# %%
import requests

# %%
TOKEN = "eyJhZGRyZXNzIjpudWxsLCJvcmdhbml6YXRpb25faWQiOiJlNjZjMTk5Zi1lYzgzLTRkNWUtYjhkOS0zZWI1NTI4MDI0YzQiLCJzZXNzaW9uX2lkIjoiNGNkNjEzYmMtMmZjMS00NDQ3LWE4NTEtOWIwMTkwN2Y2MjFiIiwiZXhwaXJlZF9hdCI6IjIwMjUtMDUtMDNUMDg6NTY6MjIuOTkyNTgxNDM2WiIsImlzX2FwaV90b2tlbiI6dHJ1ZX0="

# %%
r = requests.get("https://api.radom.com/products",headers = {"Content-Type": "application/json", "Authorization": TOKEN})

# %%
r.json()
# Out:
# [{'id': '4ba06f1b-0463-42cd-81f9-532effe7ba8e',
#   'organizationId': 'e66c199f-ec83-4d5e-b8d9-3eb5528024c4',
#   'name': '625 токенов',
#   'description': 'Для тех кто не готов тратиться',
#   'chargingIntervalSeconds': 0,
#   'currency': 'RUB',
#   'price': '100',
#   'imageUrl': '',
#   'createdAt': '2024-05-02T15:12:31.886398Z',
#   'updatedAt': '2024-05-02T15:12:31.886398Z',
#   'isInventoried': False,
#   'quantity': None,
#   'isArchived': False,
#   'meteredBudget': '0',
#   'meteredChargingInterval': 0,
#   'allowanceDuration': None,
#   'sendSubscriptionEmails': True}]

# %%
r = requests.post("https://api.radom.com/checkout_session", headers = {"Content-Type": "application/json", "Authorization": TOKEN}, json={
        "successUrl": "https://google.com",
        "lineItems": [
            {
                "productId": "4ba06f1b-0463-42cd-81f9-532effe7ba8e"
            }
        ],
        "gateway":  {
            "managed": {
                "methods": [
                    {"network": "Bitcoin"},
                    {"network": "Tron", "token": "TR7NHqjeKQxGTCi8q8ZY4pL8otSzgjLj6t"}
                ]
            }
        }
})

# %%
print(r.json())
# Out:
# {'error': 'Cannot create a checkout session with archived products.'}

# %%
r = requests.get("https://openrouter.ai/api/v1/auth/key", headers={"Authorization": "Bearer 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"})

# %%
r.json()
# Out:
# {'data': [{'id': 'openrouter/auto',
#    'name': 'Auto (best for prompt)',
#    'description': 'Depending on their size, subject, and complexity, your prompts will be sent to [Mistral Large](/models/mistralai/mistral-large) or [GPT-4 Turbo](/models/openai/gpt-4-turbo).  To see which model was used, visit [Activity](/activity).',
#    'pricing': {'prompt': '-1',
#     'completion': '-1',
#     'request': '-1',
#     'image': '-1'},
#    'context_length': 128000,
#    'architecture': {'modality': 'text',
#     'tokenizer': 'Router',
#     'instruct_type': None},
#    'top_provider': {'max_completion_tokens': None, 'is_moderated': False},
#    'per_request_limits': None},
#   {'id': 'nousresearch/nous-capybara-7b:free',
#    'name': 'Nous: Capybara 7B (free)',
# ...

# %%
TOKEN = "https://api.telegram.org/bot6296177395:AAFcN37QRXBPfZvtQ0WE8bszJErV4oWm86I/"

# %%
import requests

# %%
r = requests.request("get", TOKEN+"getMe")

# %%
print(r.json())
# Out:
# {'ok': True, 'result': {'id': 6296177395, 'is_bot': True, 'first_name': 'CarpAISupport', 'username': 'CarpAISupportBot', 'can_join_groups': True, 'can_read_all_group_messages': False, 'supports_inline_queries': False, 'can_connect_to_business': False}}

# %%
r = requests.request("get", TOKEN+"getUpdates")
print(r.json())
# Out:
# {'ok': True, 'result': [{'update_id': 431081790, 'message': {'message_id': 38, 'from': {'id': 386513759, 'is_bot': False, 'first_name': 'Андрей', 'username': 'IneedName', 'language_code': 'en'}, 'chat': {'id': 386513759, 'first_name': 'Андрей', 'username': 'IneedName', 'type': 'private'}, 'date': 1716396581, 'text': '/start 1211221', 'entities': [{'offset': 0, 'length': 6, 'type': 'bot_command'}]}}, {'update_id': 431081791, 'message': {'message_id': 39, 'from': {'id': 386513759, 'is_bot': False, 'first_name': 'Андрей', 'username': 'IneedName', 'language_code': 'en'}, 'chat': {'id': 386513759, 'first_name': 'Андрей', 'username': 'IneedName', 'type': 'private'}, 'date': 1716459311, 'text': '1'}}, {'update_id': 431081792, 'message': {'message_id': 40, 'from': {'id': 386513759, 'is_bot': False, 'first_name': 'Андрей', 'username': 'IneedName', 'language_code': 'en'}, 'chat': {'id': 386513759, 'first_name': 'Андрей', 'username': 'IneedName', 'type': 'private'}, 'date': 1716459311, 'text': 
# ...

# %%
r = requests.request("post", TOKEN+"sendMessage", json={"chat_id": 386513759, "text": "<b><i>cock</i></b> 123 cic<b><i></i></b>", "parse_mode": "HTML"})
print(r.json())
# Out:
# {'ok': True, 'result': {'message_id': 44, 'from': {'id': 6296177395, 'is_bot': True, 'first_name': 'CarpAISupport', 'username': 'CarpAISupportBot'}, 'chat': {'id': 386513759, 'first_name': 'Андрей', 'username': 'IneedName', 'type': 'private'}, 'date': 1717002850, 'text': 'Тест'}}

# %%
r = requests.request("post", TOKEN+"deleteMessage")
print(r.json())
# Out:
# {'ok': False, 'error_code': 400, 'description': 'Bad Request: chat identifier is not specified'}
